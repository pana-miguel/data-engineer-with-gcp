# %%
from pymongo import MongoClient

client = MongoClient("mongodb://admin:secret@localhost:27017")

base = client["escuelas"]
coleccion = base["estudiante"]

# %%
estudiante = ([
  {
    "nombre": "Valeria Rojas",
    "edad": 21,
    "correo": "valeria.rojas@universidad.edu",
    "carrera": "Ingeniería de Sistemas",
    "promedio": 4.5,
    "hobbies": ["ajedrez", "programación"]
  },
  {
    "nombre": "Marcos Duarte",
    "edad": 19,
    "correo": "mduarte99@gmail.com",
    "carrera": "Diseño Gráfico",
    "promedio": 3.8,
    "hobbies": ["ilustración", "fotografía"]
  },
  {
    "nombre": "Lucía Méndez",
    "edad": 24,
    "correo": "lucia.m@estudiantes.com",
    "carrera": "Medicina",
    "promedio": 4.2,
    "hobbies": ["voluntariado", "tenis"]
  },
  {
    "nombre": "Julián Castro",
    "edad": 22,
    "correo": "j.castro_dev@outlook.com",
    "carrera": "Física",
    "promedio": 4.8,
    "hobbies": ["astronomía", "guitarra"]
  },
  {
    "nombre": "Sofía Villalba",
    "edad": 20,
    "correo": "sofi.v@academia.org",
    "carrera": "Derecho",
    "promedio": 3.9,
    "hobbies": ["debate", "lectura"]
  }
]);

# %%
resultado = coleccion.insert_many(estudiante)
print("IDs insertados:", resultado.inserted_ids)
# Out:
# IDs insertados: [ObjectId('69838734088b9dc1d17c15be'), ObjectId('69838734088b9dc1d17c15bf'), ObjectId('69838734088b9dc1d17c15c0'), ObjectId('69838734088b9dc1d17c15c1'), ObjectId('69838734088b9dc1d17c15c2')]

# %%
for estudiante in coleccion.find():
    print(estudiante)
# Out:
# {'_id': ObjectId('69838734088b9dc1d17c15be'), 'nombre': 'Valeria Rojas', 'edad': 21, 'correo': 'valeria.rojas@universidad.edu', 'carrera': 'Ingeniería de Sistemas', 'promedio': 4.5, 'hobbies': ['ajedrez', 'programación']}
# {'_id': ObjectId('69838734088b9dc1d17c15bf'), 'nombre': 'Marcos Duarte', 'edad': 19, 'correo': 'mduarte99@gmail.com', 'carrera': 'Diseño Gráfico', 'promedio': 3.8, 'hobbies': ['ilustración', 'fotografía']}
# {'_id': ObjectId('69838734088b9dc1d17c15c0'), 'nombre': 'Lucía Méndez', 'edad': 24, 'correo': 'lucia.m@estudiantes.com', 'carrera': 'Medicina', 'promedio': 4.2, 'hobbies': ['voluntariado', 'tenis']}
# {'_id': ObjectId('69838734088b9dc1d17c15c1'), 'nombre': 'Julián Castro', 'edad': 22, 'correo': 'j.castro_dev@outlook.com', 'carrera': 'Física', 'promedio': 4.8, 'hobbies': ['astronomía', 'guitarra']}
# ...
